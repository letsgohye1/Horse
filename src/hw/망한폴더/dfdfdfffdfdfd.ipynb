# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\Admin\Desktop\hhh\Horse\data_preprocessing\RC_ActiveDuty_Drop.csv", encoding="utf-8-sig")

# %%
df
# Out:
#        divide  hrName     hrno jkName    jkNo     prtr prtrName  rcBudam  \
# 0           0   파이널축제    45339    함완식  080342  70170.0      김동균        2
# 1           0   아르고리치    45921    문세영  080366  70146.0      안병기        2
# 2           0   파워에치드    45734    박을운  080339  70166.0      심승태        2
# 3           0    베스트선    45369    김용근  080405  70115.0      박천서        3
# 4           0     슈어윈    45240    박태종  080103  70096.0      서범석        3
# ...       ...     ...      ...    ...     ...      ...      ...      ...
# 15943       0     스팔타    47422    조성환   80622  70164.0      박재우        3
# 15944       0   원평리스트    47322    정우주   80588  70148.0      정호익        3
# 15945       0   모어댄조크    51372    조재로   80550  70095.0      박종곤        3
# 15946       0  제이에스로드    45729    우인철   80621  70179.0      송문길        3
# 15947       0   엑설런트탄  1412210    마이아   80616  70170.0      김동균        3
#
#        rcChul rcCode  ...  rcP8Odd     rcP8Sale rcPlansu rcRank  rcTime  \
# ...

# %%
df["rcOrd"].value_counts()
# Out:
# rcOrd
# 1     1978
# 2     1778
# 3     1722
# 4     1647
# 5     1531
# 6     1484
# 7     1385
# 8     1303
# 9     1139
# 10    1018
# 11     635
# 94     113
# 95      79
# 12      73
# 92      28
# 13      11
# 15       9
# 14       8
# 93       6
# 16       1
# Name: count, dtype: int64

# %%
df["rcRank"].value_counts()
# Out:
# rcRank
# 6     4681
# 4     4296
# 5     3583
# 3     1926
# 2      740
# 1      459
# 0       57
# 7       39
# 9       34
# 10      31
# 8       30
# 11      24
# 12      21
# 13      13
# 15       7
# 14       5
# 16       2
# Name: count, dtype: int64

# %%
df.nunique()[df.nunique() == 1]
# Out:
# Series([], dtype: int64)

# %%
df["noracefl"]
# Out:
# 0        정상
# 1        정상
# 2        정상
# 3        정상
# 4        정상
#          ..
# 15943    정상
# 15944    정상
# 15945    정상
# 15946    정상
# 15947    정상
# Name: noracefl, Length: 15948, dtype: str
