# %%
import pandas as pd
df = pd.read_csv("C:/Users/Admin/Desktop/hhh/Horse/data_raw/raw_race_2023_to_2025.csv", encoding="utf-8-sig")
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_6068\2773511513.py:2: DtypeWarning: Columns (0: jkNo) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("C:/Users/Admin/Desktop/hhh/Horse/data_raw/raw_race_2023_to_2025.csv", encoding="utf-8-sig")

# %%
df.head()
# Out:
#    chaksun  diffTot  divide hrName   hrno jkName    jkNo noracefl      prow  \
# 0  2000000   12.250       0    새내칸  45818     이혁  080486       정상  117013.0
# 1        0   15.000       0   한강파워  45568    유승완  080417       정상  121008.0
# 2  1600000   13.250       0  파이널축제  45339    함완식  080342       정상  113110.0
# 3        0   21.375       0   런던비상  45409    박현우  080499       정상  121003.0
# 4        0   17.500       0   나올탱크  46372    문성혁  080587       정상  121010.0
#
#   prowName  ...  rcSex rcSpcbu rcTime  rcVtdusu  rundayth track  weath   wgHr  \
# 0      문금철  ...     오픈       1   83.3      12.0         1    양호     흐림  489.0
# 1      나기두  ...     오픈       1   83.8      12.0         1    양호     흐림  519.0
# 2      정기환  ...     오픈       1   83.5      12.0         1    양호     흐림  490.0
# 3      임현성  ...     오픈       1   85.0      12.0         1    양호     흐림  446.0
# 4     이경호a  ...     오픈       1   84.2      12.0         1    양호     흐림  532.0
#
#    test_rank  rank
# 0        4.0   4.0
# ...

# %%
print("hrNo 최소:", df['hrno'].min())
print("hrNo 최대:", df['hrno'].max())


df.count()
# Out:
# hrNo 최소: 33142
# hrNo 최대: 7114532
# chaksun      33359
# diffTot      30089
# divide       33359
# hrName       33359
# hrno         33359
# jkName       33359
# jkNo         33359
# noracefl     33359
# prow         33349
# prowName     33349
# prtr         33345
# prtrName     33343
# rcAge        32867
# rcBudam      33359
# rcChul       33359
# rcCode       33359
# rcDate       33359
# rcDiff2      33177
# rcDiff3      33238
# rcDiff4      33238
# rcDiff5      33238
# rcDist       33359
# rcFrflag     33359
# rcGrade      33359
# rcHrfor      33359
# rcHrnew      33359
# rcNo         33359
# rcNrace      33359
# rcOrd        33359
# rcP1Odd      33238
# rcP1Sale     33238
# rcP2Odd      33238
# rcP2Sale     33238
# rcP3Odd      33238
# rcP3Sale     33238
# rcP4Odd      33238
# rcP4Sale     33238
# rcP5Odd      33238
# rcP5Sale     33238
# rcP6Odd      33238
# rcP6Sale     33238
# rcP8Odd      33238
# rcP8Sale     33238
# rcPlansu     33359
# rcRank       33359
# ...

# %%
df[df['hrno'] == 33142]['hrName']
# Out:
# 1008     파티파워
# 2165     파티파워
# 3075     파티파워
# 4061     파티파워
# 5044     파티파워
# 6050     파티파워
# 6923     파티파워
# 8907     파티파워
# 10219    파티파워
# 11487    파티파워
# 12425    파티파워
# 13068    파티파워
# 14108    파티파워
# 15134    파티파워
# 16275    파티파워
# 17363    파티파워
# 18394    파티파워
# 19792    파티파워
# 20347    파티파워
# 21444    파티파워
# Name: hrName, dtype: str

# %%
df[df['hrno'] == 7114532]['hrName']
# Out:
# 7702    듀크와이
# Name: hrName, dtype: str

# %%
df["rcHrnew"]
# Out:
# 0        Rookie2
# 1        Rookie2
# 2        Rookie2
# 3        Rookie2
# 4        Rookie2
#           ...
# 33354         일반
# 33355         일반
# 33356         일반
# 33357         일반
# 33358         일반
# Name: rcHrnew, Length: 33359, dtype: str
