# %%
import pandas as pd

df = pd.read_csv("../../data_raw/raw_race_2023_to_2025.csv", encoding="utf-8-sig")

df.head()
# Out:
# /var/folders/sn/qmpsrwgx77bf6_xn90cmhyjm0000gn/T/ipykernel_7425/1491191593.py:3: DtypeWarning: Columns (0: jkNo) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../../data_raw/raw_race_2023_to_2025.csv", encoding="utf-8-sig")
#    chaksun  diffTot  divide hrName   hrno jkName    jkNo noracefl      prow  \
# 0  2000000   12.250       0    새내칸  45818     이혁  080486       정상  117013.0
# 1        0   15.000       0   한강파워  45568    유승완  080417       정상  121008.0
# 2  1600000   13.250       0  파이널축제  45339    함완식  080342       정상  113110.0
# 3        0   21.375       0   런던비상  45409    박현우  080499       정상  121003.0
# 4        0   17.500       0   나올탱크  46372    문성혁  080587       정상  121010.0
#
#   prowName  ...  rcSex rcSpcbu rcTime  rcVtdusu  rundayth track  weath   wgHr  \
# 0      문금철  ...     오픈       1   83.3      12.0         1    양호     흐림  489.0
# 1      나기두  ...     오픈       1   83.8      12.0         1    양호     흐림  519.0
# ...

# %%
df["hrno"]
# Out:
# 0        45818
# 1        45568
# 2        45339
# 3        45409
# 4        46372
#          ...
# 33354    45769
# 33355    55888
# 33356    46935
# 33357    45229
# 33358    50757
# Name: hrno, Length: 33359, dtype: int64

# %%
df["hrno"].unique()
# Out:
# array([45818, 45568, 45339, ..., 53792, 54543, 53233], shape=(3367,))

# %%
# 중복을 제거한 말의 개수
df["hrno"].nunique()
# Out:
# 3367
